# %% [markdown]
# <a href="https://colab.research.google.com/github/msminhchile0808-del/Exploring-Random-User-Data-with-Python-Pandas-and-CSV/blob/main/HW_2_Program_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Read  one of the CSV files(s) you just created into pandas
df = pd.read_csv('/content/drive/MyDrive/Adv Python for Data Analyst/Week 3/Homework 2/random_users.csv')
# Print out the pandas dataframe
df
# Out:
#     gender                                               name  \
# 0   female  {'title': 'Mrs', 'first': 'Stacy', 'last': 'Go...
# 1   female  {'title': 'Miss', 'first': 'Emma', 'last': 'Wi...
# 2   female  {'title': 'Ms', 'first': 'Janet', 'last': 'Cas...
# 3   female  {'title': 'Ms', 'first': 'Hazel', 'last': 'Bell'}
# 4   female  {'title': 'Miss', 'first': 'Teresa', 'last': '...
# 5   female  {'title': 'Mrs', 'first': 'Daisy', 'last': 'Ku...
# 6   female  {'title': 'Miss', 'first': 'Carmen', 'last': '...
# 7   female  {'title': 'Miss', 'first': 'Lena', 'last': 'Hi...
# 8   female  {'title': 'Mrs', 'first': 'Becky', 'last': 'We...
# 9   female  {'title': 'Ms', 'first': 'Scarlett', 'last': '...
# 10  female  {'title': 'Miss', 'first': 'Cherly', 'last': '...
# 11  female  {'title': 'Mrs', 'first': 'Patsy', 'last': 'Bu...
# 12  female  {'title': 'Mrs', 'first': 'Joanne', 'last': 'S...
# 13  female  {'title': 'Mrs', 'first': 'Shannon', 'last': '...
# ...
